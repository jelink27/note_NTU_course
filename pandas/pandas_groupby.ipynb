# %%
import pandas as pd

player_profile = pd.read_csv("https://python4ds.s3-ap-northeast-1.amazonaws.com/player_profile.csv")
# print(player_profile["country"].size)
# print(player_profile["country"].nunique())
# print(player_profile["country"].unique())
# print(player_profile["country"].value_counts())

print(player_profile.head())
# Out:
#                 collegeName      country dateOfBirthUTC firstName heightFeet  \
# 0                Pittsburgh  New Zealand     1993-07-20    Steven          7
# 1                  Kentucky          USA     1997-07-18       Bam          6
# 2  University of Louisville  South Sudan     1997-02-01      Deng          6
# 3                     Texas          USA     1985-07-19  LaMarcus          6
# 4                 Tennessee       Canada     1996-10-21      Kyle          6
#
#   heightInches  heightMeters  isActive  jersey           lastAffiliation  \
# 0            0          2.13         1    12.0    Pittsburgh/New Zealand
# 1           10          2.08         1    13.0              Kentucky/USA
# 2            7          2.01         1     NaN   South Sudan/South Sudan
# 3           11          2.11         1    12.0                 Texas/USA
# 4           11          2.11         1     NaN          Tennessee/Canada
#
# ...

# %%
print(player_profile["country"].size) #總共有多少rows
print(player_profile["country"].nunique()) #numbers of unique
print(player_profile["country"].unique()) #unique
print(player_profile["country"].value_counts()) #各個unique總計
# Out:
# 524
# 42
# ['New Zealand' 'USA' 'South Sudan' 'Canada' 'Greece' 'United Kingdom'
#  'Bahamas' 'France' 'Australia' 'Italy' 'Croatia' 'Latvia' 'Georgia'
#  'Democratic Republic of the Congo' 'Serbia' 'Sudan' 'Germany' 'Lithuania'
#  'Brazil' 'Slovenia' 'Switzerland' nan 'Mali' 'Senegal' 'Guinea'
#  'Cameroon' 'Angola' ' ' 'Spain' 'Yugoslavia' 'Japan' 'Dominican Republic'
#  'Turkey' 'Haiti' 'Ukraine' 'Finland' 'Bosnia and Herzegovina' 'Egypt'
#  'Nigeria' 'Austria' 'Czech Republic' 'Gabon' 'Montenegro']
# USA                                 393
# Canada                               20
# France                               12
# Australia                            10
# Croatia                               7
# Germany                               6
# Serbia                                6
# Spain                                 5
# Lithuania                             4
# Turkey                                4
# Italy                                 3
# ...

# %%
player_profile['heightMeters'].mean()
# Out:
# 2.005525812619503

# %%
groupby_object = player_profile.groupby('pos') #把groupby object實體化出來

groupby_object['heightMeters'].mean()
# Out:
# pos
# C      2.126863
# C-F    2.090000
# F      2.044378
# F-C    2.107500
# F-G    1.995333
# G      1.924800
# G-F    2.000000
# Name: heightMeters, dtype: float64
